# %% [markdown]
# # Standardizing data files
# In this notebook, we will standardize the .csv files, concatenate them into one final dataframe, and save that dataframe.

# %% [markdown]
# ## Setup

# %%
# importing libraries
import numpy as np
import pandas as pd
import os

# %%
# definnig data paths

DATA_PATHS = [
    os.path.join(
]
