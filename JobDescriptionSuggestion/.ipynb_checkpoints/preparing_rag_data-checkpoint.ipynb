# %% [markdown]
# # Preparing Data For RAG
# In this notebook, we will standardize the .csv files, concatenate them into one final dataframe, and save that dataframe.

# %% [markdown]
# ## Setup

# %%
# importing libraries
import os
import pandas as pd
import numpy as np
import ast

# %%
# defining data paths
ROOT_PATH = "./data"
CSV_PATHS = [os.path.join(ROOT_PATH, path) for path in os.listdir(ROOT_PATH) if path.endswith(".csv")]
print(CSV_PATHS)
# Out:
# ['./data\\jobs_1_data.csv', './data\\jobs_3_data.csv', './data\\jobs_4_data.csv', './data\\jobs_5_data.csv']

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Standardizing Datasets

# %% [markdown]
# **First Dataset**

# %%
CSV_PATHS[0]
# Out:
# './data\\jobs_1_data.csv'

# %%
df1 = pd.read_csv(CSV_PATHS[0])
df1.head()
# Out:
#                                                title  \
# 0    Senior Data Scientist, Research, YouTube Search
# 1                Senior AI Engineer - Data Scientist
# 2         Audio Software Engineer, Applied Scientist
# 3                Software Engineer, Machine Learning
# 4  AI / Machine Learning Research Engineer (early...
#
#                                          description  year
# 0  Note: By applying to this position you will ha...  2025
# 1  This is where you save and sustain lives\n\nAt...  2025
# 2  Redmond, WA • + 2 more•Full Time\nMessenger\nM...  2025
# 3  Bellevue, WA • Full Time\nMeta\nSoftware Engin...  2025
# 4  Job ID: 694362BR\nDate posted: May. 22, 2025\n...  2025

# %% [markdown]
# **Second Dataset**

# %%
CSV_PATHS[1]
# Out:
# './data\\jobs_3_data.csv'

# %%
df2 = pd.read_csv(CSV_PATHS[1])
df2.head()
# Out:
#                                            job_title  \
# 0  development and implementation of a federated ...
# 1                                   Data Entry  -- 2
# 2                          Build API access to data
# 3           Develop an AI website from the ground up
# 4  Develop a Linux based BT receiving daemon to "...
#
#                                      job_description  \
# 0  please bid only if you are ready to do the wor...
# 1  Project Title: Data Entry - Data Analysis in E...
# 2  Project Title: Build API access to acquired fl...
# 3  I am looking for a skilled developer to create...
# 4  I am looking for a skilled freelancer to devel...
#
#                                                 tags  year  \
# 0  ['algorithm', 'java', 'python', 'machine learn...  2024
# 1  ['excel', 'statistical analysis', 'statistics'...  2024
# 2  ['python', 'php', 'javascript', 'software arch...  2024
# 3  ['java', 'website design', 'html', 'python', '...  2024
# 4  ['linux', 'python', 'c programming', 'shell sc...  2024
#
#    description_lengths
# 0                  189
# 1                  151
# 2                  177
# 3                  136
# 4                  223

# %%
df2 = df2.copy().drop(columns = ['description_lengths'])
df2.head()
# Out:
#                                            job_title  \
# 0  development and implementation of a federated ...
# 1                                   Data Entry  -- 2
# 2                          Build API access to data
# 3           Develop an AI website from the ground up
# 4  Develop a Linux based BT receiving daemon to "...
#
#                                      job_description  \
# 0  please bid only if you are ready to do the wor...
# 1  Project Title: Data Entry - Data Analysis in E...
# 2  Project Title: Build API access to acquired fl...
# 3  I am looking for a skilled developer to create...
# 4  I am looking for a skilled freelancer to devel...
#
#                                                 tags  year
# 0  ['algorithm', 'java', 'python', 'machine learn...  2024
# 1  ['excel', 'statistical analysis', 'statistics'...  2024
# 2  ['python', 'php', 'javascript', 'software arch...  2024
# 3  ['java', 'website design', 'html', 'python', '...  2024
# 4  ['linux', 'python', 'c programming', 'shell sc...  2024

# %%
rename_dict = {
    'job_title' : 'title',
    'job_description' : 'description',
    'tags' : 'skills'
}

df2 = df2.copy().rename(columns = rename_dict)
df2.head()
# Out:
#                                                title  \
# 0  development and implementation of a federated ...
# 1                                   Data Entry  -- 2
# 2                          Build API access to data
# 3           Develop an AI website from the ground up
# 4  Develop a Linux based BT receiving daemon to "...
#
#                                          description  \
# 0  please bid only if you are ready to do the wor...
# 1  Project Title: Data Entry - Data Analysis in E...
# 2  Project Title: Build API access to acquired fl...
# 3  I am looking for a skilled developer to create...
# 4  I am looking for a skilled freelancer to devel...
#
#                                               skills  year
# 0  ['algorithm', 'java', 'python', 'machine learn...  2024
# 1  ['excel', 'statistical analysis', 'statistics'...  2024
# 2  ['python', 'php', 'javascript', 'software arch...  2024
# 3  ['java', 'website design', 'html', 'python', '...  2024
# 4  ['linux', 'python', 'c programming', 'shell sc...  2024

# %%
df2.skills.iloc[0]
# Out:
# "['algorithm', 'java', 'python', 'machine learning (ml)', 'flutter']"

# %%
ast.literal_eval(df2.skills.iloc[0])
# Out:
# ['algorithm', 'java', 'python', 'machine learning (ml)', 'flutter']

# %%
df2['skills'] = df2['skills'].apply(ast.literal_eval)
df2.head()
# Out:
#                                                title  \
# 0  development and implementation of a federated ...
# 1                                   Data Entry  -- 2
# 2                          Build API access to data
# 3           Develop an AI website from the ground up
# 4  Develop a Linux based BT receiving daemon to "...
#
#                                          description  \
# 0  please bid only if you are ready to do the wor...
# 1  Project Title: Data Entry - Data Analysis in E...
# 2  Project Title: Build API access to acquired fl...
# 3  I am looking for a skilled developer to create...
# 4  I am looking for a skilled freelancer to devel...
#
#                                               skills  year
# 0  [algorithm, java, python, machine learning (ml...  2024
# 1  [excel, statistical analysis, statistics, spss...  2024
# 2  [python, php, javascript, software architectur...  2024
# 3          [java, website design, html, python, php]  2024
# 4  [linux, python, c programming, shell script, s...  2024

# %% [markdown]
# **Third Dataset**

# %%
CSV_PATHS[2]
# Out:
# './data\\jobs_4_data.csv'

# %%
df3 = pd.read_csv(CSV_PATHS[2])
df3.head()
# Out:
#                                  Position  \
# 0   1926/07 Senior Java Software Engineer
# 1      1st / 2nd Line IT Support Engineer
# 2  2037/03 Middle/Senior Python Developer
# 3  2037/03 Middle/Senior Python Developer
# 4                      24/7 Junior DevOps
#
#                                          description  \
# 0  **Your responsibilities**\r\n- Take ownership ...
# 1  THE ROLE:\r\nOur Engineers help small business...
# 2  **A stable long term project, growing customer...
# 3  Looking for an experienced Python engineer who...
# 4  **Qualifications and experience:**\r\n- Interm...
#
#               Refined_Category
# 0   Software & Web Development
# 1  Administrative & Data Entry
# 2   Software & Web Development
# 3   Software & Web Development
# 4      DevOps & Infrastructure

# %%
rename_dict = {
    'Position' : 'title',
    'Refined_Category' : 'category'
}

df3 = df3.copy().rename(columns = rename_dict)
df3.head()
# Out:
#                                     title  \
# 0   1926/07 Senior Java Software Engineer
# 1      1st / 2nd Line IT Support Engineer
# 2  2037/03 Middle/Senior Python Developer
# 3  2037/03 Middle/Senior Python Developer
# 4                      24/7 Junior DevOps
#
#                                          description  \
# 0  **Your responsibilities**\r\n- Take ownership ...
# 1  THE ROLE:\r\nOur Engineers help small business...
# 2  **A stable long term project, growing customer...
# 3  Looking for an experienced Python engineer who...
# 4  **Qualifications and experience:**\r\n- Interm...
#
#                       category
# 0   Software & Web Development
# 1  Administrative & Data Entry
# 2   Software & Web Development
# 3   Software & Web Development
# 4      DevOps & Infrastructure

# %%
# !!!
df3['year'] = 2023

df3.head()
# Out:
#                                     title  \
# 0   1926/07 Senior Java Software Engineer
# 1      1st / 2nd Line IT Support Engineer
# 2  2037/03 Middle/Senior Python Developer
# 3  2037/03 Middle/Senior Python Developer
# 4                      24/7 Junior DevOps
#
#                                          description  \
# 0  **Your responsibilities**\r\n- Take ownership ...
# 1  THE ROLE:\r\nOur Engineers help small business...
# 2  **A stable long term project, growing customer...
# 3  Looking for an experienced Python engineer who...
# 4  **Qualifications and experience:**\r\n- Interm...
#
#                       category  year
# 0   Software & Web Development  2023
# 1  Administrative & Data Entry  2023
# 2   Software & Web Development  2023
# 3   Software & Web Development  2023
# 4      DevOps & Infrastructure  2023

# %% [markdown]
# **Fourth Dataset**

# %%
CSV_PATHS[3]
# Out:
# './data\\jobs_5_data.csv'

# %%
df4 = pd.read_csv(CSV_PATHS[3])
df4.head()
# Out:
#                                            Job Title  \
# 0  File Maker Pro Reports, Charts, Query and Ongo...
# 1  BI and Data Engineer for Upwork Finance System...
# 2  Computer vision / machine learning: synthetic ...
# 3                           Expert in Data Analytics
# 4     Data Analytics Expert for Educational Exercise
#
#                                          Description   best_category
# 0  NITIAL PROJECT\r\n\r\nSet up Monthly Report mi...    Data Analyst
# 1  The Upwork Finance Systems team is looking for...    Data Analyst
# 2  Our company is working on a government proposa...  Video Producer
# 3  Mission : Ensure smooth transition of Analytic...    Data Analyst
# 4  Looking for someone to help me solve some prob...    Data Analyst

# %%
rename_dict = {
    'Job Title' : 'title',
    'Description' : 'description',
    'best_category' : 'category'
}

df4 = df4.copy().rename(columns = rename_dict)
df4.head()
# Out:
#                                                title  \
# 0  File Maker Pro Reports, Charts, Query and Ongo...
# 1  BI and Data Engineer for Upwork Finance System...
# 2  Computer vision / machine learning: synthetic ...
# 3                           Expert in Data Analytics
# 4     Data Analytics Expert for Educational Exercise
#
#                                          description        category
# 0  NITIAL PROJECT\r\n\r\nSet up Monthly Report mi...    Data Analyst
# 1  The Upwork Finance Systems team is looking for...    Data Analyst
# 2  Our company is working on a government proposa...  Video Producer
# 3  Mission : Ensure smooth transition of Analytic...    Data Analyst
# 4  Looking for someone to help me solve some prob...    Data Analyst

# %%
df4['year'] = 2023

df4.head()
# Out:
#                                                title  \
# 0  File Maker Pro Reports, Charts, Query and Ongo...
# 1  BI and Data Engineer for Upwork Finance System...
# 2  Computer vision / machine learning: synthetic ...
# 3                           Expert in Data Analytics
# 4     Data Analytics Expert for Educational Exercise
#
#                                          description        category  year
# 0  NITIAL PROJECT\r\n\r\nSet up Monthly Report mi...    Data Analyst  2023
# 1  The Upwork Finance Systems team is looking for...    Data Analyst  2023
# 2  Our company is working on a government proposa...  Video Producer  2023
# 3  Mission : Ensure smooth transition of Analytic...    Data Analyst  2023
# 4  Looking for someone to help me solve some prob...    Data Analyst  2023

# %% [markdown]
# **Text Files**

# %%
TXT_ROOT_PATH = 'data/jobs_2_data/'
position_paths = [os.path.join(TXT_ROOT_PATH, position) for position in os.listdir(TXT_ROOT_PATH)]

print(position_paths)
# Out:
# ['data/jobs_2_data/AI Engineer', 'data/jobs_2_data/Backend Developer', 'data/jobs_2_data/Content Writer', 'data/jobs_2_data/Data Analyst', 'data/jobs_2_data/DevOps Engineer', 'data/jobs_2_data/Frontend Developer', 'data/jobs_2_data/Graphic Designer', 'data/jobs_2_data/Mobile Developer', 'data/jobs_2_data/Video Producer']

# %%
def load_txt_file(path):
    with open(path, 'r') as f:
        content = f.read()
    return content

# %%
import re
def extract_data(job: str):
    job = job.split(']')[1].strip()
    lines = job.split("\n\n")
    return {
        'title' : lines[0].split(":")[1].strip(),
        'responsibilities' : lines[1].split(":")[1].strip().split(", "),
        'tech_skills' : lines[2].split(":")[1].strip().split(", "),
        'tools' : lines[3].split(":")[1].strip().split(", "),
        'soft_skills' : lines[4].split(":")[1].strip().split(", "),
    }

# %%
def format_data(data: dict) -> str:
    """
    Turns the data dictionary into a formal job description.
    """    
    def to_bullets(items):
        cleaned_items = []
        for item in items:
            # Remove "and " if it's at the start of the string
            clean_item = item.strip()
            if clean_item.lower().startswith("and "):
                clean_item = clean_item[4:]
            
            # Capitalize the first letter and add bullet
            cleaned_items.append(f"• {clean_item.capitalize()}")
        
        return "\n".join(cleaned_items)

    job_desc = f"""
Key Responsibilities
{to_bullets(data.get('responsibilities', []))}

Technical Skills
{to_bullets(data.get('tech_skills', []))}

Soft Skills
{to_bullets(data.get('soft_skills', []))}

Tools & Software
{to_bullets(data.get('tools', []))}
"""
    return job_desc

# %%
# reading the .txt jobs into csv
txt_data = []
for pos_idx, pos_folder in enumerate(position_paths, start = 1):
    position = pos_folder.split("/")[-1]
    print(f'>> Position #_{pos_idx} - {position}')

    # all files in that position folder
    n_error_files = 0
    for file_idx, file in enumerate(os.listdir(pos_folder)):
        try:
            print(end = "\t")
            print(f'Finished {file_idx} files')
            
            # skip `Fundamental skills & Recent Trends`
            if "Job" not in file:
                continue
            
            # read file
            file_path = os.path.join(pos_folder, file)
            file_content = load_txt_file(file_path)
            data = extract_data(file_content)
    
            # extract data
            title = data['title']
            description = format_data(data)
            year = 2026
    
            # save
            txt_data.append({
                'title' : title,
                'description' : description,
                'year' : year
            })

        # skip errornos files
        except:
            n_error_files += 1
            pass

    print(f"Number of Files with Errors: {n_error_files}")

    print()
    print()
# Out:
# >> Position #_1 - AI Engineer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_2 - Backend Developer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_3 - Content Writer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_4 - Data Analyst
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 1
#
#
# >> Position #_5 - DevOps Engineer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_6 - Frontend Developer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_7 - Graphic Designer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_8 - Mobile Developer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0
#
#
# >> Position #_9 - Video Producer
# 	Finished 0 files
# 	Finished 1 files
# 	Finished 2 files
# 	Finished 3 files
# 	Finished 4 files
# 	Finished 5 files
# 	Finished 6 files
# 	Finished 7 files
# 	Finished 8 files
# 	Finished 9 files
# 	Finished 10 files
# 	Finished 11 files
# Number of Files with Errors: 0

# %%
txt_to_df = pd.DataFrame(txt_data)
txt_to_df.head()
# Out:
#                                                title  \
# 0     Senior AI Engineer (Production-grade systems).
# 1  Machine Learning Developer (Sports Betting Str...
# 2  Senior Data Scientist / Applied AI Engineer (E...
# 3   ML/NLP Engineer (Foundational & Strategy Focus).
# 4  Computer Vision Engineer (Padel Sports Analyti...
#
#                                          description  year
# 0  \nKey Responsibilities\n• Designing rag pipeli...  2026
# 1  \nKey Responsibilities\n• Creating predictive ...  2026
# 2  \nKey Responsibilities\n• Designing multi-moda...  2026
# 3  \nKey Responsibilities\n• Designing scalable d...  2026
# 4  \nKey Responsibilities\n• Improving player tra...  2026

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Concatenating Datasets

# %%
df_final = pd.concat(
    objs = [df1, df2, df3, df4, txt_to_df],
    axis = 0
)

# %%
df_final.head(n = 10)
# Out:
#                                                title  \
# 0    Senior Data Scientist, Research, YouTube Search
# 1                Senior AI Engineer - Data Scientist
# 2         Audio Software Engineer, Applied Scientist
# 3                Software Engineer, Machine Learning
# 4  AI / Machine Learning Research Engineer (early...
# 5   Staff Data Scientist, Research, Search Platforms
# 6     Applied AI/ML, Senior Associate - Gen AI & LLM
# 7          Executive Director, ML and Ad Marketplace
# 8                                     AI/ML Engineer
# 9                   Senior Software Engineer - AI/ML
#
#                                          description  year skills category
# 0  Note: By applying to this position you will ha...  2025    NaN      NaN
# 1  This is where you save and sustain lives\n\nAt...  2025    NaN      NaN
# 2  Redmond, WA • + 2 more•Full Time\nMessenger\nM...  2025    NaN      NaN
# 3  Bellevue, WA • Full Time\nMeta\nSoftware Engin...  2025    NaN      NaN
# 4  Job ID: 694362BR\nDate posted: May. 22, 2025\n...  2025    NaN      NaN
# 5  Note: By applying to this position you will ha...  2025    NaN      NaN
# 6  JOB DESCRIPTION\n\nLeverage your technical exp...  2025    NaN      NaN
# 7  Universal Ads, a part of Comcast, enables any ...  2025    NaN      NaN
# 8  Riverside Overview: Riverside Research is an i...  2025    NaN      NaN
# 9  Why Mayo Clinic\n\nMayo Clinic is top-ranked i...  2025    NaN      NaN

# %%
df_final.tail(n = 10)
# Out:
#                                                 title  \
# 79  Video Production Specialist (Multi-Platform Co...
# 80  SaaS Video Producer (Software Demo & Feature S...
# 81  Videographer & Location Scout (Corporate/Talk-...
# 82  Short-Form Ad Creator (eCommerce & Performance...
# 83  Whiteboard Animator / Explainer Video Specialist.
# 84  Video Producer (Non-Profit & Event Presentatio...
# 85  Motion Graphics Designer & Product Video Speci...
# 86  Motion Graphics Artist & Video Producer (SaaS ...
# 87  Podcast & Video Production Specialist (Multi-P...
# 88  Video Production Specialist (Scripting & Editi...
#
#                                           description  year skills category
# 79  \nKey Responsibilities\n• Conceptualizing and ...  2026    NaN      NaN
# 80  \nKey Responsibilities\n• Writing concise\n• B...  2026    NaN      NaN
# 81  \nKey Responsibilities\n• Scouting and securin...  2026    NaN      NaN
# 82  \nKey Responsibilities\n• Developing simple ad...  2026    NaN      NaN
# 83  \nKey Responsibilities\n• Executing a 2\n\nTec...  2026    NaN      NaN
# 84  \nKey Responsibilities\n• Producing a long-for...  2026    NaN      NaN
# 85  \nKey Responsibilities\n• Translating existing...  2026    NaN      NaN
# 86  \nKey Responsibilities\n• Executing high-quali...  2026    NaN      NaN
# 87  \nKey Responsibilities\n• Editing raw audio fo...  2026    NaN      NaN
# 88  \nKey Responsibilities\n• Developing engaging ...  2026    NaN      NaN

# %%
df_final.shape
# Out:
# (36207, 5)

# %%
df_final.to_csv(path_or_buf = 'data/final_data.csv')

# %%
df_final.isna().sum()
# Out:
# title              0
# description        0
# year               0
# skills         33163
# category        3845
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# ***Alhamdulillah***
